# %%
# 指定された内容でリストを作成
array = [
    "月曜日は晴れです",       # 0
    "火曜日は雨です",         # 1
    "水曜日は晴れです",       # 2
    "木曜日は晴れです",       # 3
    "金曜日は曇りです",       # 4
    "土曜日は曇りのち雨です", # 5
    "日曜日は雷雨です"        # 6
]

dictionary = {
    "mon": "晴れ",
    "tue": "雨",
    "wed": "晴れ",
    "thu": "晴れ",
    "fri": "曇り",
    "sat": "曇りのち雨",
    "sun": "雷雨"
}

# 水曜日の天気予報を出力
print(array[2])
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
